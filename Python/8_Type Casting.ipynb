# %% [markdown]
# # Type Casting

# %% [markdown]
# #### Type casting refers to the process of converting one data type into another. Python provides several built-in functions for type casting, allowing you to convert variables from one type to another

# %% [markdown]
# ### int()
# Converts a value to an integer.

# %%
float_num = 3.14
int_num = int(float_num)
print(int_num)
# Out:
# 3

# %% [markdown]
# ### float()
# Converts a value to a floating-point number.

# %%
int_num = 5
float_num = float(int_num)
print(float_num)
# Out:
# 5.0

# %% [markdown]
# ### str()
# Converts a value to a string.

# %%
num = 42
str_num = str(num)
print(str_num)
# Out:
# 42

# %%
type(str_num)
# Out:
# str

# %% [markdown]
# ### bool()
# Converts a value to a boolean.

# %%
num = 0
bool_value = bool(num)
print(bool_value)
# Out:
# False

# %%
num = 1
bool_value = bool(num)
print(bool_value)
# Out:
# True

# %%
num = 5
bool_value = bool(num)
print(bool_value)
# Out:
# True

# %% [markdown]
# ## Exercise

# %% [markdown]
# ### Challenge 1: String to Integer
# <b>Objectives:</b>
#
# 1. Prompt the user to enter their age as a string.
# 2. Convert the string to an integer using int().
# 3. Print the age as a number.

# %%
age = input("Enter your age: ")
age = int(age)
print(age)
# Out:
# 21

# %% [markdown]
# ### Challenge 2: Integer to Float
#
# <b>Objectives:</b>
#
# 1. Prompt the user to enter the radius of a circle as an integer.
# 2. Convert the integer radius to a float using float().
# 3. Calculate the area of the circle using the formula: area = 3.14 * radius * radius.
# 4. Print the calculated area.

# %%
r = int(input("Enter the radius of circle: "))
r = float(r)
area = 3.14*r*r
print("Area is: ", area)
# Out:
# Area is:  78.5
