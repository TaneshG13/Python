# %% [markdown]
# # Exercise 2

# %% [markdown]
# ### Q. Write a program to calculate circumference of circle

# %%
import math

# %%
radius = float(input("Enter the radius of a circle: "))
circumference = 2 * math.pi * radius
print(f"The Circumference of the circle is: {round(circumference,2)}")
# Out:
# Enter the radius of a circle:  10.6
# The Circumference of the circle is: 66.6

# %% [markdown]
# ### Q. Write a program to calculate Area of circle

# %%
radius = float(input("Enter the radius of a circle: "))
area = math.pi * math.pow(radius, 2)
print(f"The Area of the circle is: {round(area,2)}")
# Out:
# Enter the radius of a circle:  5
# The Area of the circle is: 78.54

# %% [markdown]
# ### Q. Write a program to calculate hypotaneus of right angled triangle

# %%
height = float(input("Enter the height of a Triangle: "))
base = float(input("Enter the base of a Triangle: "))
hypo = math.sqrt(math.pow(height,2)+math.pow(base,2))
print(f"The Area of the circle is: {round(hypo,2)}")
# Out:
# Enter the height of a Triangle:  5
# Enter the base of a Triangle:  3
# The Area of the circle is: 5.83
