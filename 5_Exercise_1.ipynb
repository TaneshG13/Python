# %% [markdown]
# # Exercise 1

# %% [markdown]
# ### Q1: Calculate the are of rectangle. Take length and width from user as inputs.

# %%
length = float(input("Enter the Lenght of the rectangle: "))
width = float(input("Enter the width of the rectangle: "))
area = length * width
print(f"Area of the rectangle is: {area}")
# Out:
# Enter the Lenght of the rectangle:  5
# Enter the width of the rectangle:  7
# Area of the rectangle is: 35.0

# %% [markdown]
# ### Q2: Shopping Cart Program. (Billing system)

# %%
item = input("What item  would you like to buy?: ")
price = float(input("What is the price?: "))
quantity = int (input("How many would you like?: "))
amount = price * quantity
print(f"Your bill for {item} is {amount} $")
# Out:
# What item  would you like to buy?:  Mangos
# What is the price?:  5
# How many would you like?:  10
# Your bill for Mangos is 50.0 $
