# %% [markdown]
# # input()

# %% [markdown]
# <b>A function that prompts the user to enter data and Returns the entered data as string</b>

# %%
name = input("What is you name: ")
print(f"Hello! {name}")
# Out:
# What is you name:  Jhon
# Hello! Jhon

# %%
age = int(input("What is your age: "))
print(f"Your age is: {age}")
# Out:
# What is your age:  21
# Your age is: 21
